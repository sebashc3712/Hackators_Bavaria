# %%
import pandas as pd
import numpy as np

# %%
customers=pd.read_csv('Input1_clientes_estructura.csv',sep=';')

# %%
customers.head()
# Out:
#    Cliente   Regional2   Gerencia2   SubCanal2    Categoria  Nevera
# 0        1  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       0
# 1        2  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       0
# 2        3  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       0
# 3        4  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       1
# 4        5  Regional 1  Gerencia_1  Subcanal_1  Categoria_2       1

# %%
customers.shape
# Out:
# (20921, 6)

# %%
sales=pd.read_csv('Input2_clientes_venta.csv',sep=';')

# %%
sales.head()
# Out:
#     Año  Mes  Cliente   SegmentoPrecio2   Marca2   Cupo2    CapacidadEnvase2  \
# 0  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_1  CapacidadEnvase_12
# 1  2019    5       10  SegmentoPrecio_1  Marca_2  Cupo_2  CapacidadEnvase_10
# 2  2019    5       10  SegmentoPrecio_2  Marca_3  Cupo_2  CapacidadEnvase_10
# 3  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_2  CapacidadEnvase_16
# 4  2019    5       10  SegmentoPrecio_1  Marca_4  Cupo_2  CapacidadEnvase_10
#
#     Volumen       disc          nr
# 0  0.112229 -30.590603  900.328567
# 1  0.021734   0.000000  149.184463
# 2  0.043469   0.000000  359.625828
# 3  0.026345 -31.065261  134.748399
# 4  0.086938   0.000000  496.901005

# %%
sales.shape
# Out:
# (1406116, 10)

# %%
test=pd.read_csv('Input3_clientes_test.csv',sep=';')

# %%
test.head()
# Out:
#    Cliente  Marca1  Marca2  Marca3  Marca_Inno1  Marca_Inno2
# 0       10     NaN     NaN     NaN          NaN          NaN
# 1       12     NaN     NaN     NaN          NaN          NaN
# 2       14     NaN     NaN     NaN          NaN          NaN
# 3       15     NaN     NaN     NaN          NaN          NaN
# 4       18     NaN     NaN     NaN          NaN          NaN

# %%
train=pd.merge(left=sales,right=customers,how='left',on='Cliente')

# %%
train.head()
# Out:
#     Año  Mes  Cliente   SegmentoPrecio2   Marca2   Cupo2    CapacidadEnvase2  \
# 0  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_1  CapacidadEnvase_12
# 1  2019    5       10  SegmentoPrecio_1  Marca_2  Cupo_2  CapacidadEnvase_10
# 2  2019    5       10  SegmentoPrecio_2  Marca_3  Cupo_2  CapacidadEnvase_10
# 3  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_2  CapacidadEnvase_16
# 4  2019    5       10  SegmentoPrecio_1  Marca_4  Cupo_2  CapacidadEnvase_10
#
#     Volumen       disc          nr   Regional2   Gerencia2   SubCanal2  \
# 0  0.112229 -30.590603  900.328567  Regional 1  Gerencia_3  Subcanal_1
# 1  0.021734   0.000000  149.184463  Regional 1  Gerencia_3  Subcanal_1
# 2  0.043469   0.000000  359.625828  Regional 1  Gerencia_3  Subcanal_1
# 3  0.026345 -31.065261  134.748399  Regional 1  Gerencia_3  Subcanal_1
# 4  0.086938   0.000000  496.901005  Regional 1  Gerencia_3  Subcanal_1
#
#      Categoria  Nevera
# 0  Categoria_2       1
# 1  Categoria_2       1
# 2  Categoria_2       1
# 3  Categoria_2       1
# 4  Categoria_2       1

# %%
train.shape
# Out:
# (1406116, 15)

# %%
products_to_score=pd.read_excel('Product_To_Score.xlsx', sheets='Sheet1')

# %%
products_to_score
# Out:
#    ID    Marca2   Cupo2     CapacidadEnvase
# 0   1  Marca_20  Cupo_3   CapacidadEnvase_9
# 1   2  Marca_16  Cupo_2  CapacidadEnvase_10
# 2   3   Marca_9  Cupo_2  CapacidadEnvase_12
# 3   4  Marca_38  Cupo_2  CapacidadEnvase_10
# 4   5  Marca_39  Cupo_2  CapacidadEnvase_10

# %%
test['Mes']=10
test['Año']=2020

# %%
test=pd.merge(left=test,right=customers,how='left',on='Cliente')

# %%
test.head()
# Out:
#    Cliente  Marca1  Marca2  Marca3  Marca_Inno1  Marca_Inno2  Mes   Año  \
# 0       10     NaN     NaN     NaN          NaN          NaN   10  2020
# 1       12     NaN     NaN     NaN          NaN          NaN   10  2020
# 2       14     NaN     NaN     NaN          NaN          NaN   10  2020
# 3       15     NaN     NaN     NaN          NaN          NaN   10  2020
# 4       18     NaN     NaN     NaN          NaN          NaN   10  2020
#
#     Regional2   Gerencia2   SubCanal2    Categoria  Nevera
# 0  Regional 1  Gerencia_3  Subcanal_1  Categoria_2       1
# 1  Regional 1  Gerencia_3  Subcanal_4  Categoria_4       1
# 2  Regional 1  Gerencia_3  Subcanal_1  Categoria_2       1
# 3  Regional 1  Gerencia_2  Subcanal_3  Categoria_2       1
# 4  Regional 1  Gerencia_3  Subcanal_1  Categoria_5       1

# %%
products=train.groupby(['Marca2', 'Cupo2','CapacidadEnvase2','SegmentoPrecio2'],as_index=False)['Volumen'].sum()

# %%
products
# Out:
#        Marca2   Cupo2    CapacidadEnvase2   SegmentoPrecio2       Volumen
# 0     Marca_1  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_1  21881.290980
# 1     Marca_1  Cupo_1  CapacidadEnvase_14  SegmentoPrecio_1   7651.761163
# 2     Marca_1  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_1      0.070867
# 3     Marca_1  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_1  65633.972325
# 4     Marca_1  Cupo_2  CapacidadEnvase_16  SegmentoPrecio_1  41205.673338
# 5     Marca_1  Cupo_2  CapacidadEnvase_17  SegmentoPrecio_1   7236.672309
# 6     Marca_1  Cupo_2   CapacidadEnvase_5  SegmentoPrecio_1    149.928979
# 7    Marca_10  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_1    170.079276
# 8    Marca_10  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_1    382.434253
# 9    Marca_11  Cupo_3   CapacidadEnvase_2  SegmentoPrecio_3      2.154077
# 10   Marca_11  Cupo_3   CapacidadEnvase_3  SegmentoPrecio_3    384.612502
# 11   Marca_12  Cupo_1  CapacidadEnvase_10  SegmentoPrecio_2    475.566181
# 12   Marca_12  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_2     44.917925
# 13   Marca_12  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_2    409.184960
# 14   Marca_12  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_2      2.043034
# 15   Marca_13  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_2    108.860393
# 16   Marca_13  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_2      4.829385
# 17   Marca_14  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_1    117.707503
# 18   Marca_14  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_1    140.236905
# 19   Marca_14  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_1      4.049844
# 20   Marca_15  Cupo_1  CapacidadEnvase_10  SegmentoPrecio_1     61.435195
# 21   Marca_15  Cupo_2  CapacidadEnvase_11  SegmentoPrecio_1   5127.555055
# 22   Marca_15  Cupo_2  CapacidadEnvase_16  SegmentoPrecio_1    262.111991
# 23   Marca_16  Cupo_1  CapacidadEnvase_10  SegmentoPrecio_2    790.155039
# 24   Marca_16  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_2      2.505659
# 25   Marca_16  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_2      5.573125
# 26   Marca_16  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_2    555.307542
# 27   Marca_16  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_2      4.415707
# 28   Marca_16  Cupo_5  CapacidadEnvase_17  SegmentoPrecio_2      0.131724
# 29   Marca_17  Cupo_1  CapacidadEnvase_10  SegmentoPrecio_1    836.562342
# ..        ...     ...                 ...               ...           ...
# 75    Marca_4  Cupo_2  CapacidadEnvase_16  SegmentoPrecio_1   4522.378205
# 76    Marca_4  Cupo_2  CapacidadEnvase_17  SegmentoPrecio_1    175.089298
# 77    Marca_4  Cupo_2   CapacidadEnvase_4  SegmentoPrecio_1      0.075082
# 78    Marca_4  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_1      3.286242
# 79    Marca_4  Cupo_5  CapacidadEnvase_17  SegmentoPrecio_1      5.049407
# 80    Marca_5  Cupo_1  CapacidadEnvase_10  SegmentoPrecio_1   9594.065058
# 81    Marca_5  Cupo_1  CapacidadEnvase_14  SegmentoPrecio_1   1380.815161
# 82    Marca_5  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_1     39.320150
# 83    Marca_5  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_1  45552.076360
# 84    Marca_5  Cupo_2  CapacidadEnvase_16  SegmentoPrecio_1  16907.627130
# 85    Marca_5  Cupo_2  CapacidadEnvase_17  SegmentoPrecio_1   2040.564304
# 86    Marca_5  Cupo_2   CapacidadEnvase_5  SegmentoPrecio_1      7.549962
# 87    Marca_5  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_1    103.292762
# 88    Marca_6  Cupo_1  CapacidadEnvase_10  SegmentoPrecio_2   4286.300804
# 89    Marca_6  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_2    250.059276
# 90    Marca_6  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_2     29.327856
# 91    Marca_6  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_2   8162.696515
# 92    Marca_6  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_2     57.473738
# 93    Marca_6  Cupo_5  CapacidadEnvase_17  SegmentoPrecio_2     16.992353
# 94    Marca_7  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_3      5.307476
# 95    Marca_7  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_3   3954.486440
# 96    Marca_7  Cupo_3   CapacidadEnvase_5  SegmentoPrecio_3    889.713260
# 97    Marca_7  Cupo_3   CapacidadEnvase_8  SegmentoPrecio_3    128.246429
# 98    Marca_8  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_1    342.569742
# 99    Marca_8  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_1   1223.163080
# 100   Marca_8  Cupo_3   CapacidadEnvase_1  SegmentoPrecio_1      2.074648
# 101   Marca_8  Cupo_3  CapacidadEnvase_10  SegmentoPrecio_1      1.360574
# 102   Marca_9  Cupo_3  CapacidadEnvase_12  SegmentoPrecio_3   4945.818641
# 103   Marca_9  Cupo_3  CapacidadEnvase_15  SegmentoPrecio_3    172.786790
# 104   Marca_9  Cupo_3   CapacidadEnvase_3  SegmentoPrecio_3   1117.125460
#
# [105 rows x 5 columns]

# %%
products=products.drop('Volumen',axis=1)
products.head()
# Out:
#     Marca2   Cupo2    CapacidadEnvase2   SegmentoPrecio2
# 0  Marca_1  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_1
# 1  Marca_1  Cupo_1  CapacidadEnvase_14  SegmentoPrecio_1
# 2  Marca_1  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_1
# 3  Marca_1  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_1
# 4  Marca_1  Cupo_2  CapacidadEnvase_16  SegmentoPrecio_1

# %%
products['Llave']=products.Marca2+products.Cupo2+products.CapacidadEnvase2
products.reset_index(inplace=True)
products.head()
# Out:
#    index   Marca2   Cupo2    CapacidadEnvase2   SegmentoPrecio2  \
# 0      0  Marca_1  Cupo_1  CapacidadEnvase_12  SegmentoPrecio_1
# 1      1  Marca_1  Cupo_1  CapacidadEnvase_14  SegmentoPrecio_1
# 2      2  Marca_1  Cupo_1   CapacidadEnvase_6  SegmentoPrecio_1
# 3      3  Marca_1  Cupo_2  CapacidadEnvase_10  SegmentoPrecio_1
# 4      4  Marca_1  Cupo_2  CapacidadEnvase_16  SegmentoPrecio_1
#
#                              Llave
# 0  Marca_1Cupo_1CapacidadEnvase_12
# 1  Marca_1Cupo_1CapacidadEnvase_14
# 2   Marca_1Cupo_1CapacidadEnvase_6
# 3  Marca_1Cupo_2CapacidadEnvase_10
# 4  Marca_1Cupo_2CapacidadEnvase_16

# %%
test=test.drop(['Marca1','Marca2','Marca3','Marca_Inno1','Marca_Inno2'],axis=1)

# %%
test1=test.copy()
test2=test.copy()
test3=test.copy()
test4=test.copy()
test5=test.copy()

# %%
test1['Marca2']=1
test2['Marca2']=2
test3['Marca2']=3
test4['Marca2']=4
test5['Marca2']=5

# %%
test=test1.append([test2,test3,test4,test5])

# %%
test.tail()
# Out:
#       Cliente  Mes   Año   Regional2    Gerencia2   SubCanal2    Categoria  \
# 9297    20186   10  2020  Regional 1   Gerencia_9  Subcanal_7  Categoria_1
# 9298    20261   10  2020  Regional 1  Gerencia_10  Subcanal_1  Categoria_2
# 9299    20309   10  2020  Regional 1  Gerencia_10  Subcanal_3  Categoria_3
# 9300    20360   10  2020  Regional 1  Gerencia_10  Subcanal_8  Categoria_1
# 9301    20569   10  2020  Regional 1   Gerencia_6  Subcanal_3  Categoria_2
#
#       Nevera  Marca2
# 9297       0       5
# 9298       0       5
# 9299       0       5
# 9300       0       5
# 9301       0       5

# %%
train['Llave']=train.Marca2+train.Cupo2+train.CapacidadEnvase2

# %%
products_to_score['Llave']=products_to_score.Marca2+products_to_score.Cupo2+products_to_score.CapacidadEnvase

# %%
train=pd.merge(left=train,right=products_to_score[['Llave','ID']],how='left',on='Llave')

# %%
train.head()
# Out:
#     Año  Mes  Cliente   SegmentoPrecio2   Marca2   Cupo2    CapacidadEnvase2  \
# 0  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_1  CapacidadEnvase_12
# 1  2019    5       10  SegmentoPrecio_1  Marca_2  Cupo_2  CapacidadEnvase_10
# 2  2019    5       10  SegmentoPrecio_2  Marca_3  Cupo_2  CapacidadEnvase_10
# 3  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_2  CapacidadEnvase_16
# 4  2019    5       10  SegmentoPrecio_1  Marca_4  Cupo_2  CapacidadEnvase_10
#
#     Volumen       disc          nr   Regional2   Gerencia2   SubCanal2  \
# 0  0.112229 -30.590603  900.328567  Regional 1  Gerencia_3  Subcanal_1
# 1  0.021734   0.000000  149.184463  Regional 1  Gerencia_3  Subcanal_1
# 2  0.043469   0.000000  359.625828  Regional 1  Gerencia_3  Subcanal_1
# 3  0.026345 -31.065261  134.748399  Regional 1  Gerencia_3  Subcanal_1
# 4  0.086938   0.000000  496.901005  Regional 1  Gerencia_3  Subcanal_1
#
#      Categoria  Nevera                            Llave  ID
# 0  Categoria_2       1  Marca_1Cupo_1CapacidadEnvase_12 NaN
# 1  Categoria_2       1  Marca_2Cupo_2CapacidadEnvase_10 NaN
# 2  Categoria_2       1  Marca_3Cupo_2CapacidadEnvase_10 NaN
# 3  Categoria_2       1  Marca_1Cupo_2CapacidadEnvase_16 NaN
# 4  Categoria_2       1  Marca_4Cupo_2CapacidadEnvase_10 NaN

# %%
train.shape
# Out:
# (1406116, 17)

# %%
train['ID']=train.ID.fillna(0)

# %%
train.head()
# Out:
#     Año  Mes  Cliente   SegmentoPrecio2   Marca2   Cupo2    CapacidadEnvase2  \
# 0  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_1  CapacidadEnvase_12
# 1  2019    5       10  SegmentoPrecio_1  Marca_2  Cupo_2  CapacidadEnvase_10
# 2  2019    5       10  SegmentoPrecio_2  Marca_3  Cupo_2  CapacidadEnvase_10
# 3  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_2  CapacidadEnvase_16
# 4  2019    5       10  SegmentoPrecio_1  Marca_4  Cupo_2  CapacidadEnvase_10
#
#     Volumen       disc          nr   Regional2   Gerencia2   SubCanal2  \
# 0  0.112229 -30.590603  900.328567  Regional 1  Gerencia_3  Subcanal_1
# 1  0.021734   0.000000  149.184463  Regional 1  Gerencia_3  Subcanal_1
# 2  0.043469   0.000000  359.625828  Regional 1  Gerencia_3  Subcanal_1
# 3  0.026345 -31.065261  134.748399  Regional 1  Gerencia_3  Subcanal_1
# 4  0.086938   0.000000  496.901005  Regional 1  Gerencia_3  Subcanal_1
#
#      Categoria  Nevera                            Llave   ID
# 0  Categoria_2       1  Marca_1Cupo_1CapacidadEnvase_12  0.0
# 1  Categoria_2       1  Marca_2Cupo_2CapacidadEnvase_10  0.0
# 2  Categoria_2       1  Marca_3Cupo_2CapacidadEnvase_10  0.0
# 3  Categoria_2       1  Marca_1Cupo_2CapacidadEnvase_16  0.0
# 4  Categoria_2       1  Marca_4Cupo_2CapacidadEnvase_10  0.0

# %%
train=train.drop('Llave',axis=1)

# %%
train.shape
# Out:
# (1406116, 16)

# %%
train.columns
# Out:
# Index(['Año', 'Mes', 'Cliente', 'SegmentoPrecio2', 'Marca2', 'Cupo2',
#        'CapacidadEnvase2', 'Volumen', 'disc', 'nr', 'Regional2', 'Gerencia2',
#        'SubCanal2', 'Categoria', 'Nevera', 'ID'],
#       dtype='object')

# %%
test.columns = ['Cliente', 'Mes', 'Año', 'Regional2', 'Gerencia2', 'SubCanal2',
       'Categoria', 'Nevera', 'ID']
test.head()
# Out:
#    Cliente  Mes   Año   Regional2   Gerencia2   SubCanal2    Categoria  \
# 0       10   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_2
# 1       12   10  2020  Regional 1  Gerencia_3  Subcanal_4  Categoria_4
# 2       14   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_2
# 3       15   10  2020  Regional 1  Gerencia_2  Subcanal_3  Categoria_2
# 4       18   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_5
#
#    Nevera  ID
# 0       1   1
# 1       1   1
# 2       1   1
# 3       1   1
# 4       1   1

# %%
test = pd.merge(left=test, right=products_to_score, how = 'left', on = 'ID')

# %%
test.drop('Llave', inplace=True, axis=1)
test.columns = ['Cliente', 'Mes', 'Año', 'Regional2', 'Gerencia2', 'SubCanal2',
       'Categoria', 'Nevera', 'ID', 'Marca2', 'Cupo2', 'CapacidadEnvase2']
test.head()
# Out:
#    Cliente  Mes   Año   Regional2   Gerencia2   SubCanal2    Categoria  \
# 0       10   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_2
# 1       12   10  2020  Regional 1  Gerencia_3  Subcanal_4  Categoria_4
# 2       14   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_2
# 3       15   10  2020  Regional 1  Gerencia_2  Subcanal_3  Categoria_2
# 4       18   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_5
#
#    Nevera  ID    Marca2   Cupo2   CapacidadEnvase2
# 0       1   1  Marca_20  Cupo_3  CapacidadEnvase_9
# 1       1   1  Marca_20  Cupo_3  CapacidadEnvase_9
# 2       1   1  Marca_20  Cupo_3  CapacidadEnvase_9
# 3       1   1  Marca_20  Cupo_3  CapacidadEnvase_9
# 4       1   1  Marca_20  Cupo_3  CapacidadEnvase_9

# %%
test['Llave']=test.Marca2+test.Cupo2+test.CapacidadEnvase2
test = pd.merge(left=test, right=products[['Llave', 'SegmentoPrecio2']], how='left', on = 'Llave')
test.drop('Llave', inplace=True, axis=1)
test.head()
# Out:
#    Cliente  Mes   Año   Regional2   Gerencia2   SubCanal2    Categoria  \
# 0       10   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_2
# 1       12   10  2020  Regional 1  Gerencia_3  Subcanal_4  Categoria_4
# 2       14   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_2
# 3       15   10  2020  Regional 1  Gerencia_2  Subcanal_3  Categoria_2
# 4       18   10  2020  Regional 1  Gerencia_3  Subcanal_1  Categoria_5
#
#    Nevera  ID    Marca2   Cupo2   CapacidadEnvase2   SegmentoPrecio2
# 0       1   1  Marca_20  Cupo_3  CapacidadEnvase_9  SegmentoPrecio_1
# 1       1   1  Marca_20  Cupo_3  CapacidadEnvase_9  SegmentoPrecio_1
# 2       1   1  Marca_20  Cupo_3  CapacidadEnvase_9  SegmentoPrecio_1
# 3       1   1  Marca_20  Cupo_3  CapacidadEnvase_9  SegmentoPrecio_1
# 4       1   1  Marca_20  Cupo_3  CapacidadEnvase_9  SegmentoPrecio_1

# %%
test['Volumen'] = 0
test['disc'] = 0
test['nr'] = 0
test = test[['Año', 'Mes', 'Cliente', 'SegmentoPrecio2', 'Marca2', 'Cupo2',
       'CapacidadEnvase2', 'Volumen', 'disc', 'nr', 'Regional2', 'Gerencia2',
       'SubCanal2', 'Categoria', 'Nevera', 'ID']]
test.head()
# Out:
#     Año  Mes  Cliente   SegmentoPrecio2    Marca2   Cupo2   CapacidadEnvase2  \
# 0  2020   10       10  SegmentoPrecio_1  Marca_20  Cupo_3  CapacidadEnvase_9
# 1  2020   10       12  SegmentoPrecio_1  Marca_20  Cupo_3  CapacidadEnvase_9
# 2  2020   10       14  SegmentoPrecio_1  Marca_20  Cupo_3  CapacidadEnvase_9
# 3  2020   10       15  SegmentoPrecio_1  Marca_20  Cupo_3  CapacidadEnvase_9
# 4  2020   10       18  SegmentoPrecio_1  Marca_20  Cupo_3  CapacidadEnvase_9
#
#    Volumen  disc  nr   Regional2   Gerencia2   SubCanal2    Categoria  Nevera  \
# 0        0     0   0  Regional 1  Gerencia_3  Subcanal_1  Categoria_2       1
# 1        0     0   0  Regional 1  Gerencia_3  Subcanal_4  Categoria_4       1
# 2        0     0   0  Regional 1  Gerencia_3  Subcanal_1  Categoria_2       1
# 3        0     0   0  Regional 1  Gerencia_2  Subcanal_3  Categoria_2       1
# 4        0     0   0  Regional 1  Gerencia_3  Subcanal_1  Categoria_5       1
#
#    ID
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1

# %%
df = train.append(test, sort=False)

# %%
df.tail()
# Out:
#         Año  Mes  Cliente   SegmentoPrecio2    Marca2   Cupo2  \
# 46505  2020   10    20186  SegmentoPrecio_3  Marca_39  Cupo_2
# 46506  2020   10    20261  SegmentoPrecio_3  Marca_39  Cupo_2
# 46507  2020   10    20309  SegmentoPrecio_3  Marca_39  Cupo_2
# 46508  2020   10    20360  SegmentoPrecio_3  Marca_39  Cupo_2
# 46509  2020   10    20569  SegmentoPrecio_3  Marca_39  Cupo_2
#
#          CapacidadEnvase2  Volumen  disc   nr   Regional2    Gerencia2  \
# 46505  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1   Gerencia_9
# 46506  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1  Gerencia_10
# 46507  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1  Gerencia_10
# 46508  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1  Gerencia_10
# 46509  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1   Gerencia_6
#
#         SubCanal2    Categoria  Nevera   ID
# 46505  Subcanal_7  Categoria_1       0  5.0
# 46506  Subcanal_1  Categoria_2       0  5.0
# 46507  Subcanal_3  Categoria_3       0  5.0
# 46508  Subcanal_8  Categoria_1       0  5.0
# 46509  Subcanal_3  Categoria_2       0  5.0

# %%
df.shape
# Out:
# (1452626, 16)

# %%
df['Llave']=df.Marca2+df.Cupo2+df.CapacidadEnvase2
df = df.merge(products[['Llave', 'index']], how='left', on = 'Llave')
df.drop('Llave', inplace=True, axis=1)
df.columns = ['Año', 'Mes', 'Cliente', 'SegmentoPrecio2', 'Marca2', 'Cupo2',
       'CapacidadEnvase2', 'Volumen', 'disc', 'nr', 'Regional2', 'Gerencia2',
       'SubCanal2', 'Categoria', 'Nevera', 'target_id', 'product_id']

# %%
df.tail()
# Out:
#           Año  Mes  Cliente   SegmentoPrecio2    Marca2   Cupo2  \
# 1452621  2020   10    20186  SegmentoPrecio_3  Marca_39  Cupo_2
# 1452622  2020   10    20261  SegmentoPrecio_3  Marca_39  Cupo_2
# 1452623  2020   10    20309  SegmentoPrecio_3  Marca_39  Cupo_2
# 1452624  2020   10    20360  SegmentoPrecio_3  Marca_39  Cupo_2
# 1452625  2020   10    20569  SegmentoPrecio_3  Marca_39  Cupo_2
#
#            CapacidadEnvase2  Volumen  disc   nr   Regional2    Gerencia2  \
# 1452621  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1   Gerencia_9
# 1452622  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1  Gerencia_10
# 1452623  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1  Gerencia_10
# 1452624  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1  Gerencia_10
# 1452625  CapacidadEnvase_10      0.0   0.0  0.0  Regional 1   Gerencia_6
#
#           SubCanal2    Categoria  Nevera  target_id  product_id
# 1452621  Subcanal_7  Categoria_1       0        5.0        70.0
# 1452622  Subcanal_1  Categoria_2       0        5.0        70.0
# 1452623  Subcanal_3  Categoria_3       0        5.0        70.0
# 1452624  Subcanal_8  Categoria_1       0        5.0        70.0
# 1452625  Subcanal_3  Categoria_2       0        5.0        70.0

# %%
df.shape
# Out:
# (1452626, 17)

# %%
df.to_csv('df.csv')

# %%
result = []
for year in list(df['Año'].unique()):
    for month in list(df[df['Año']==year]['Mes'].unique()):
        for customer in list(df['Cliente'].unique()):
            result.append([year, month, customer])

matrix = pd.DataFrame(result, columns = ['year', 'month', 'customer'])
matrix['Llave'] = matrix.year.astype(str) + '_' + matrix.month.astype(str)

# %%
len(list(df['Cliente'].unique()))
# Out:
# 17010

# %%
periods = df.groupby(['Año', 'Mes'], as_index=False)['Volumen'].sum()
periods.drop('Volumen', inplace=True, axis=1)
periods = periods.sort_values(by = ['Año', 'Mes'])
periods.reset_index(inplace=True)
periods.columns = ['period', 'year', 'month']
periods['Llave'] = periods.year.astype(str) + '_' + periods.month.astype(str)

# %%
matrix = matrix.merge(periods[['period', 'Llave']] , how='left', on = 'Llave')
matrix.tail()
# Out:
#         year  month  customer    Llave  period
# 306175  2020     10     20529  2020_10      17
# 306176  2020     10     20567  2020_10      17
# 306177  2020     10     20569  2020_10      17
# 306178  2020     10     20577  2020_10      17
# 306179  2020     10     20580  2020_10      17

# %%
len(list(pd.read_csv('Input2_clientes_venta.csv', sep = ';').Cliente.unique()))
# Out:
# 17010

# %%
def lag_feature(df, lags, col):
    tmp = df[['period','Client','product_id',col]]
    for i in lags:
        shifted = tmp.copy()
        shifted.columns = ['date_block_num','shop_id','item_id', col+'_lag_'+str(i)]
        shifted['date_block_num'] += i
        df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df
